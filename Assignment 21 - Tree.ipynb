# %%
'''
Question-1

You are given a binary tree. The binary tree is represented using the TreeNode class. Each TreeNode has an integer value

and left and right children, represented using the TreeNode class itself. Convert this binary tree into a binary search

tree.

Input:

        10

       /   \

     2      7

   /   \

 8      4

Output:

        8

      /   \

    4     10

  /   \

2      7

'''

class TreeNode:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

def inorderTraversal(node, values):
    if node is None:
        return

    inorderTraversal(node.left, values)
    values.append(node.value)
    inorderTraversal(node.right, values)

def assignValues(node, values, index):
    if node is None:
        return index

    index = assignValues(node.left, values, index)
    node.value = values[index]
    index += 1
    index = assignValues(node.right, values, index)

    return index

def convertToBST(root):
    if root is None:
        return None

    values = []
    inorderTraversal(root, values)
    values.sort()

    assignValues(root, values, 0)

    return root

def inorderTraversalBST(node):
    if node is None:
        return []

    return inorderTraversalBST(node.left) + [node.value] + inorderTraversalBST(node.right)

root = TreeNode(10)
root.left = TreeNode(2)
root.right = TreeNode(7)
root.left.left = TreeNode(8)
root.left.right = TreeNode(4)

converted_bst = convertToBST(root)

print("Inorder traversal of the converted BST:", inorderTraversalBST(converted_bst))
# Out:
# Inorder traversal of the converted BST: [2, 4, 7, 8, 10]

# %%
'''
Question-2:

Given a Binary Search Tree with all unique values and two keys. Find the distance between two nodes in BST. The given keys

always exist in BST.

Example:

Consider the following BST:

Input-1:

n = 9

values = [8, 3, 1, 6, 4, 7, 10, 14,13]

node-1 = 6

node-2 = 14

Output-1:

The distance between the two keys = 4

Input-2:

n = 9

values = [8, 3, 1, 6, 4, 7, 10, 14,13]

node-1 = 3

node-2 = 4

Output-2:

The distance between the two keys = 2

'''

class TreeNode:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

def findDistance(root, node1, node2):
    if root is None:
        return 0

    if node1 < root.value and node2 < root.value:
        return findDistance(root.left, node1, node2)

    if node1 > root.value and node2 > root.value:
        return findDistance(root.right, node1, node2)

    return distanceFromNode(root, node1) + distanceFromNode(root, node2)

def distanceFromNode(node, target):
    distance = 0
    while node.value != target:
        if target < node.value:
            node = node.left
        else:
            node = node.right
        distance += 1
    return distance

root = TreeNode(8)
root.left = TreeNode(3)
root.right = TreeNode(10)
root.left.left = TreeNode(1)
root.left.right = TreeNode(6)
root.left.right.left = TreeNode(4)
root.left.right.right = TreeNode(7)
root.right.right = TreeNode(14)
root.right.right.left = TreeNode(13)

node1 = 6
node2 = 14
distance = findDistance(root, node1, node2)

print("The distance between the two keys:", distance)
# Out:
# The distance between the two keys: 4

# %%
'''
Question-3:

Write a program to convert a binary tree to a doubly linked list.

Input:

        10

       /   \

     5     20

           /   \

        30     35

Output:

5 10 30 20 35


'''

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def convert_binary_tree_to_doubly_linked_list(root):
    if root is None:
        return None

    current = root
    prev = None

    while current is not None:
        next = current.right
        current.right = prev

        if prev is not None:
            prev.left = current

        prev = current
        current = next

    return prev

def print_doubly_linked_list(head):
    current = head
    while current is not None:
        print(current.data, end=" ")
        current = current.right

if __name__ == "__main__":
    root = Node(10)
    root.left = Node(5)
    root.right = Node(20)
    root.right.left = Node(30)
    root.right.right = Node(35)

    head = convert_binary_tree_to_doubly_linked_list(root)
    print_doubly_linked_list(head)
# Out:
# 35 20 10

# %%
'''
Question-4:

Write a program to connect nodes at the same level.

Input:

        1

      /   \

    2      3

  /   \   /   \

4     5 6    7

Output:

1 → -1

2 → 3

3 → -1

4 → 5

5 → 6

6 → 7

7 → -1

'''

class TreeNode:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None
        self.nextRight = None

def connectNodesAtSameLevel(root):
    if root is None:
        return root

    queue = []
    queue.append(root)

    while queue:
        level_size = len(queue)

        for i in range(level_size):
            current = queue.pop(0)

            if i == level_size - 1:
                current.nextRight = None
            else:
                current.nextRight = queue[0]

            if current.left:
                queue.append(current.left)
            if current.right:
                queue.append(current.right)

    return root

# Example usage
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
root.right.left = TreeNode(6)
root.right.right = TreeNode(7)

connected_tree = connectNodesAtSameLevel(root)

current = connected_tree
while current:
    print(current.value, end=" → ")
    if current.nextRight:
        print(current.nextRight.value)
    else:
        print("-1")
    current = current.nextRight
# Out:
# 1 → -1
